# %% [markdown]
# Q1. Explain GET and POST methods.
#
# Ans-
#
# GET METHOD - it is used to retrive data from the server . when user submit GET request the data is sent as part of the url . this means data is visible in the url
#
# POST METHOD- it is used to submit data to server . when user submit a POST request the  data is send as body  of the http protocol . this means data is not visible URL and can not be bookmarked or cached by the browser

# %% [markdown]
# Q2. Why is request used in Flask?
#
# Ans -
# In Flask, the request object is used to access and handle incoming HTTP requests made to your web application. It provides a convenient way to retrieve data from the client (e.g., web browser) that is sent as part of an HTTP request. The request object is an essential part of building dynamic web applications as it allows you to access various aspects of the request, including form data, query parameters, headers, cookies, and more. Here are some key reasons why the request object is used in Flask:

# %% [markdown]
# Q3. Why is redirect() used in Flask?
#
# Ans -
#
# IN Flask . redirect () is a function that is used to redirect the clint to a different URL

# %% [markdown]
# Q4. What are templates in Flask? Why is the render_template() function used?
#
# Ans -
#
# in Flask , templates() is a file that contain HTML and other dynamic elements , such as variable and control structure
#
# the render_template() function in flask is used to render a template to generate a dynamic HTML page.

# %% [markdown]
# Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.
#
# Ans -

# %% [markdown]
# ![Screenshot (33).jpg](attachment:18ed1519-3500-43da-8636-b53fa569463f.jpg)

# %% [markdown]
# ![Screenshot (34).png](attachment:de1bda7f-3901-4ca4-892c-47507344acd8.png)
